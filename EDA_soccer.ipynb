# %%
import sqlite3
import os
import pandas as pd
from datetime import datetime
con = sqlite3.connect('database/database.sqlite')

# %%
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", con)
tables
# Out:
#                 name
# 0    sqlite_sequence
# 1  Player_Attributes
# 2             Player
# 3              Match
# 4             League
# 5            Country
# 6               Team
# 7    Team_Attributes

# %%
df_countries = pd.read_sql_query('Select * from Country', con)
df_countries.head()
# Out:
#       id     name
# 0      1  Belgium
# 1   1729  England
# 2   4769   France
# 3   7809  Germany
# 4  10257    Italy

# %% [markdown]
# data dictionary For country:

# %% [markdown]
# |column name|descrption|
# | :--- | :--- |
# |id|unique country id|
# |name|country name|

# %%
df_countries.shape
# Out:
# (11, 2)

# %%
df_countries.dtypes
# Out:
# id       int64
# name    object
# dtype: object

# %%
# Rows containing duplicate data
duplicate_rows_df = df_countries[df_countries.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 2)

# %%
print(df_countries.isnull().sum())
# Out:
# id      0
# name    0
# dtype: int64

# %%
df_countries.to_csv("soccer_dataset/Country.csv")

# %%
df_Player_Attributes = pd.read_sql_query('Select * from Player_Attributes', con)
df_Player_Attributes.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %% [markdown]
# data dictionary For Player_Attributes:

# %% [markdown]
# |column name|descrption|
# | :--- | :--- |
# |id|player attribute id|
# |player_fifa_api_id       | player fifa api id|
# |player_api_id            | player api id|
# |date                    | Date of the match|
# |overall_rating         | over all rating|
# |potential              | potential |
# |preferred_foot          | preffered foor|
# |attacking_work_rate     | attacking work rate|
# |defensive_work_rate     | defensive work rate|
# |crossing               | crossings|
# |finishing              | finsihings|
# |heading_accuracy       | accuracy at the headings|
# |short_passing          | short passes|
# |volleys                | volleys|
# |dribbling              | dribbling|
# |curve                  | curves |
# |free_kick_accuracy     | free kicks|
# |long_passing           | long passing |
# |ball_control           | ball in control|
# |acceleration           | acceleration|
# |sprint_speed           | sprint speed |
# |agility                | agility |
# |reactions              | reactions|
# |balance                | balance|
# |shot_power             | shot power|
# |jumping                | jumping|
# |stamina                | stamina|
# |strength               | strength |
# |long_shots             | long shots|
# |aggression             | aggression|
# |interceptions          | interceptions|
# |positioning            | positioning|
# |vision                 | vision|
# |penalties              | penalties |
# |marking                | marking|
# |standing_tackle        | standing tackle|
# |sliding_tackle         | sliding tackle|
# |gk_diving              | GK diving|
# |gk_handling            | gk handling|
# |gk_kicking             | gk kicking|
# |gk_positioning         |gk positioning|
# |gk_reflexes            |gk reflexes|

# %%
df_Player_Attributes.dtypes
# Out:
# id                       int64
# player_fifa_api_id       int64
# player_api_id            int64
# date                    object
# overall_rating         float64
# potential              float64
# preferred_foot          object
# attacking_work_rate     object
# defensive_work_rate     object
# crossing               float64
# finishing              float64
# heading_accuracy       float64
# short_passing          float64
# volleys                float64
# dribbling              float64
# curve                  float64
# free_kick_accuracy     float64
# long_passing           float64
# ball_control           float64
# acceleration           float64
# sprint_speed           float64
# agility                float64
# reactions              float64
# balance                float64
# shot_power             float64
# jumping                float64
# stamina                float64
# strength               float64
# long_shots             float64
# aggression             float64
# ...

# %%
# Rows containing duplicate data
duplicate_rows_df = df_Player_Attributes[df_Player_Attributes.duplicated()]
print('number of duplicate rows: ', duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 42)

# %%
df_Player_Attributes.shape
# Out:
# (183978, 42)

# %%
print(df_Player_Attributes.isnull().sum())
# Out:
# id                        0
# player_fifa_api_id        0
# player_api_id             0
# date                      0
# overall_rating          836
# potential               836
# preferred_foot          836
# attacking_work_rate    3230
# defensive_work_rate     836
# crossing                836
# finishing               836
# heading_accuracy        836
# short_passing           836
# volleys                2713
# dribbling               836
# curve                  2713
# free_kick_accuracy      836
# long_passing            836
# ball_control            836
# acceleration            836
# sprint_speed            836
# agility                2713
# reactions               836
# balance                2713
# shot_power              836
# jumping                2713
# stamina                 836
# strength                836
# long_shots              836
# aggression              836
# interceptions           836
# positioning             836
# vision                 2713
# ...

# %%
df_Player_Attributes.describe()
# Out:
#                  id  player_fifa_api_id  player_api_id  overall_rating  \
# count  183978.00000       183978.000000  183978.000000   183142.000000
# mean    91989.50000       165671.524291  135900.617324       68.600015
# std     53110.01825        53851.094769  136927.840510        7.041139
# min         1.00000            2.000000    2625.000000       33.000000
# 25%     45995.25000       155798.000000   34763.000000       64.000000
# 50%     91989.50000       183488.000000   77741.000000       69.000000
# 75%    137983.75000       199848.000000  191080.000000       73.000000
# max    183978.00000       234141.000000  750584.000000       94.000000
#
#            potential       crossing      finishing  heading_accuracy  \
# count  183142.000000  183142.000000  183142.000000     183142.000000
# mean       73.460353      55.086883      49.921078         57.266023
# std         6.592271      17.242135      19.038705         16.488905
# ...

# %%
# removing the na values
df_Player_Attributes=df_Player_Attributes.dropna()

# %%
print(df_Player_Attributes.isnull().sum())
# Out:
# id                     0
# player_fifa_api_id     0
# player_api_id          0
# date                   0
# overall_rating         0
# potential              0
# preferred_foot         0
# attacking_work_rate    0
# defensive_work_rate    0
# crossing               0
# finishing              0
# heading_accuracy       0
# short_passing          0
# volleys                0
# dribbling              0
# curve                  0
# free_kick_accuracy     0
# long_passing           0
# ball_control           0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# long_shots             0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# ...

# %%
df_Player_Attributes.to_csv("soccer_dataset/PlayerAttrbutes.csv")

# %%
df_player = pd.read_sql_query('Select * from Player', con)
df_player.head()
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
df_player.dtypes
# Out:
# id                      int64
# player_api_id           int64
# player_name            object
# player_fifa_api_id      int64
# birthday               object
# height                float64
# weight                  int64
# dtype: object

# %% [markdown]
# data dictionary for Players:

# %% [markdown]
# |column name|descrption|
# | :--- | :--- |
# |id|unique id|
# |player_api_id| player api id|
# |player_name|player name|
# |player_fifa_api_id| player fifa api id|
# |birthday| birthday|
# |height|height|
# |weight|weight|

# %%
df_player.shape
# Out:
# (11060, 7)

# %%
print(df_player.isnull().sum())
# Out:
# id                    0
# player_api_id         0
# player_name           0
# player_fifa_api_id    0
# birthday              0
# height                0
# weight                0
# dtype: int64

# %%
df_player.to_csv("soccer_dataset/Players.csv")

# %%
df_match = pd.read_sql_query('Select * from Match', con)
df_match.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...   \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# ...

# %%
df_match.shape
# Out:
# (25979, 115)

# %%
df_match.dtypes
# Out:
# id                    int64
# country_id            int64
# league_id             int64
# season               object
# stage                 int64
# date                 object
# match_api_id          int64
# home_team_api_id      int64
# away_team_api_id      int64
# home_team_goal        int64
# away_team_goal        int64
# home_player_X1      float64
# home_player_X2      float64
# home_player_X3      float64
# home_player_X4      float64
# home_player_X5      float64
# home_player_X6      float64
# home_player_X7      float64
# home_player_X8      float64
# home_player_X9      float64
# home_player_X10     float64
# home_player_X11     float64
# away_player_X1      float64
# away_player_X2      float64
# away_player_X3      float64
# away_player_X4      float64
# away_player_X5      float64
# away_player_X6      float64
# away_player_X7      float64
# away_player_X8      float64
#                      ...
# B365H               float64
# B365D               float64
# ...

# %%
df_match.to_csv("soccer_dataset/Match.csv")

# %%
df_league = pd.read_sql_query('Select * from League', con)
df_league.head()
# Out:
#       id  country_id                    name
# 0      1           1  Belgium Jupiler League
# 1   1729        1729  England Premier League
# 2   4769        4769          France Ligue 1
# 3   7809        7809   Germany 1. Bundesliga
# 4  10257       10257           Italy Serie A

# %%
df_league.to_csv("soccer_dataset/League.csv")

# %%
df_team = pd.read_sql_query('Select * from Team', con)
df_team.head()
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
df_team.to_csv("soccer_dataset/Team.csv")

# %%
df_Team_Attributes = pd.read_sql_query('Select * from Team_Attributes', con)
df_Team_Attributes.head()
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
# 2   3               434         9930  2015-09-10 00:00:00                47
# 3   4                77         8485  2010-02-22 00:00:00                70
# 4   5                77         8485  2011-02-22 00:00:00                47
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
# 2              Balanced                  41.0                    Normal
# 3                  Fast                   NaN                    Little
# 4              Balanced                   NaN                    Little
#
#    buildUpPlayPassing buildUpPlayPassingClass           ...             \
# ...

# %%
df_Team_Attributes.isnull().sum()
# Out:
# id                                  0
# team_fifa_api_id                    0
# team_api_id                         0
# date                                0
# buildUpPlaySpeed                    0
# buildUpPlaySpeedClass               0
# buildUpPlayDribbling              969
# buildUpPlayDribblingClass           0
# buildUpPlayPassing                  0
# buildUpPlayPassingClass             0
# buildUpPlayPositioningClass         0
# chanceCreationPassing               0
# chanceCreationPassingClass          0
# chanceCreationCrossing              0
# chanceCreationCrossingClass         0
# chanceCreationShooting              0
# chanceCreationShootingClass         0
# chanceCreationPositioningClass      0
# defencePressure                     0
# defencePressureClass                0
# defenceAggression                   0
# defenceAggressionClass              0
# defenceTeamWidth                    0
# defenceTeamWidthClass               0
# defenceDefenderLineClass            0
# ...

# %%
df_Team_Attributes.to_csv("soccer_dataset/TeamAttributes.csv")
